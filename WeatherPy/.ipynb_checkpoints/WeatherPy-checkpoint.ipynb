# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_key import api_key
from pprint import pprint

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#import weather map wrapper
import openweathermapy as owm

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %%
#create cities dataframe
cities_df = pd.DataFrame(cities)

#rename header for cities column
cities_df = cities_df.rename(columns={0: 'City'})
cities_df
# Out:
#               City
# 0             asau
# 1     longyearbyen
# 2          skeldon
# 3        busselton
# 4             sola
# ..             ...
# 597    miandrivazo
# 598        ligayan
# 599    meadow lake
# 600     lavrentiya
# 601  traverse city
#
# [602 rows x 1 columns]

# %%
cities_df["Cloudiness"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df["Humidity"] = "" 
cities_df["Lat"] = ""
cities_df["Lng"]  = ""
cities_df["Max Temp"] = ""
cities_df["Wind Speed"] = ""
# cities_df.head()

#wrapper
settings = {"units": "imperial", "appid": api_key}

#create weather series
wx_data_series = []

#counter for api calls to set limit at 60
api_calls = 0

for index, row in cities_df.iterrows():
    try:
        wx_data_series.append(owm.get_current(row[0], **settings))
        print(f'City # {index}: {row[0]}')
        cities_df.loc[index, "Cloudiness"] = wx_data_series[index]["clouds"]["all"]
        cities_df.loc[index, "Country"] = wx_data_series[index]["sys"]["country"]
        cities_df.loc[index, "Date"] = wx_data_series[index]["dt"]
        cities_df.loc[index, "Humidity"] = wx_data_series[index]["main"]["humidity"]
        cities_df.loc[index, "Lat"] = wx_data_series[index]["coord"]["lat"]
        cities_df.loc[index, "Lng"] = wx_data_series[index]["coord"]["lon"]
        cities_df.loc[index, "Max Temp"] = wx_data_series[index]["main"]["temp_max"]
        cities_df.loc[index, "Wind Speed"] = wx_data_series[index]["wind"]["speed"]
        
    except Exception as e:

        wx_data_series.append(f"{row[0]} not found.")
        
    api_calls +=1
    
    if api_calls >=60:
        time.sleep(60)
        api_calls = 0
        
    continue
# Out:
# City # 1: longyearbyen
# City # 2: skeldon
# City # 3: busselton
# City # 4: sola
# City # 7: vaini
# City # 8: jurm
# City # 9: arraial do cabo
# City # 10: soyo
# City # 11: touros
# City # 12: mataura
# City # 14: trinidad
# City # 16: puerto ayora
# City # 17: tiksi
# City # 18: yellowknife
# City # 19: leningradskiy
# City # 20: kloulklubed
# City # 21: lebu
# City # 22: jamestown
# City # 23: hermanus
# City # 27: dikson
# City # 28: hobart
# City # 30: ahuimanu
# City # 34: nikolskoye
# City # 35: bluff
# City # 36: deputatskiy
# City # 37: bambous virieux
# City # 38: new norfolk
# City # 39: castro
# City # 40: alofi
# City # 41: namibe
# City # 42: cape town
# City # 43: geraldton
# City # 44: hilo
# City # 45: mar del plata
# City # 46: cidreira
# City # 47: faanui
# City # 48: sibate
# City # 49: hithadhoo
# City # 51: chokurdakh
# City # 52: georgetown
# City # 53: yakeshi
# City # 54: rikitea
# City # 55: zhigansk
# City # 56: ushuaia
# City # 57: talnakh
# City # 58: sao filipe
# City # 59: naze
# City # 60: fairbanks
# City # 61: mandalgovi
# City # 62: mehamn
# City # 63: atuona
# City # 64: esperance
# City # 65: kavaratti
# City # 66: bulri
# City # 67: laguna
# City # 68: samoded
# City # 69: kruisfontein
# City # 70: hirara
# City # 71: saint george
# City # 548: souillac
# City # 549: maragogi
# City # 550: wattegama
# City # 551: bandarbeyla
# City # 552: paragominas
# City # 553: olutanga
# City # 554: ilula
# City # 555: kisangani
# City # 556: san andres
# City # 557: ciudad bolivar
# City # 558: guider
# City # 559: sibolga
# City # 560: ayni
# City # 561: myre
# City # 562: mto wa mbu
# City # 563: puerto madryn
# City # 564: ginir
# City # 565: san jeronimo
# City # 566: princeton
# City # 567: nampula
# City # 568: mattru
# City # 569: okato
# City # 571: peniche
# City # 572: tokur
# City # 575: burnie
# City # 576: hualmay
# City # 577: pierre
# City # 578: albury
# City # 579: vestmannaeyjar
# City # 580: tarabha
# City # 581: dalbandin
# City # 582: san bartolo
# City # 583: tromso
# City # 584: gat
# City # 585: calama
# City # 586: plettenberg bay
# City # 587: debar
# City # 588: placido de castro
# City # 589: san francisco del mar
# City # 590: smoljan
# City # 591: solec kujawski
# City # 592: emba
# City # 593: nieuw amsterdam
# City # 594: socorro
# City # 595: ixtapa
# City # 596: wanaka
# City # 597: miandrivazo
# City # 598: ligayan
# City # 599: meadow lake
# City # 600: lavrentiya
# City # 601: traverse city

# %%
cities_df
# Out:
#               City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0             asau
# 1     longyearbyen         90      NO  1574571491       85  78.22   15.63
# 2          skeldon         61      GY  1574571753       82   5.88  -57.13
# 3        busselton        100      AU  1574571334       22 -33.64  115.35
# 4             sola        100      TZ  1574571753       88  -3.17    33.8
# ..             ...        ...     ...         ...      ...    ...     ...
# 597    miandrivazo         60      MG  1574572375       53 -19.53   45.46
# 598        ligayan         15      PH  1574572375       66   4.65  119.47
# 599    meadow lake         53      CA  1574572375       81  54.13 -108.44
# 600     lavrentiya         17      RU  1574572435       78  65.58 -170.99
# 601  traverse city          1      US  1574572435       92  44.76  -85.62
#
#     Max Temp Wind Speed
# 0
# 1       19.4      10.29
# 2      80.87      12.26
# 3         81      12.91
# 4      65.12       4.56
# ..       ...        ...
# 597    85.32       1.86
# 598    84.42       2.46
# 599    32.34      10.51
# 600    10.74      16.91
# 601     33.8       12.1
#
# [602 rows x 9 columns]

# %%
cities_df['Cloudiness'].replace('', np.nan, inplace=True)

# %%
cities_df.dropna(subset=['Cloudiness'],inplace=True)

# %%
cities_df.count()
# Out:
# City          531
# Cloudiness    531
# Country       531
# Date          531
# Humidity      531
# Lat           531
# Lng           531
# Max Temp      531
# Wind Speed    531
# dtype: int64

# %%
cities_df
# Out:
#               City  Cloudiness Country        Date Humidity    Lat     Lng  \
# 1     longyearbyen        90.0      NO  1574571491       85  78.22   15.63
# 2          skeldon        61.0      GY  1574571753       82   5.88  -57.13
# 3        busselton       100.0      AU  1574571334       22 -33.64  115.35
# 4             sola       100.0      TZ  1574571753       88  -3.17    33.8
# 7            vaini         0.0      IN  1574571399       64  15.34   74.49
# ..             ...         ...     ...         ...      ...    ...     ...
# 597    miandrivazo        60.0      MG  1574572375       53 -19.53   45.46
# 598        ligayan        15.0      PH  1574572375       66   4.65  119.47
# 599    meadow lake        53.0      CA  1574572375       81  54.13 -108.44
# 600     lavrentiya        17.0      RU  1574572435       78  65.58 -170.99
# 601  traverse city         1.0      US  1574572435       92  44.76  -85.62
#
#     Max Temp Wind Speed
# 1       19.4      10.29
# 2      80.87      12.26
# 3         81      12.91
# 4      65.12       4.56
# 7       73.4      11.41
# ..       ...        ...
# 597    85.32       1.86
# 598    84.42       2.46
# 599    32.34      10.51
# 600    10.74      16.91
# 601     33.8       12.1
#
# [531 rows x 9 columns]

# %%
cities_df.to_csv("Cities.csv", encoding="utf-8", index=False)

# %%
# Temperature (F) vs. Latitude

plt.figure(figsize=(15, 10))
plt.grid(True, zorder=1)
plt.scatter(cities_df["Lat"], cities_df["Max Temp"], marker="H", color = 'purple', zorder=2)
plt.title(f"City Latitude vs Max Temperature (" + time.strftime("%m/%d/%Y") + ")", fontsize=24)
plt.xlabel("City Latitude", fontsize=18)
plt.ylabel("Max Temperature (Fahrenheit)", fontsize=18)
plt.savefig("LATvsMAXTEMP.png")
plt.show()

# %%
# Humidity (%) vs. Latitude

plt.figure(figsize=(15, 10))
plt.grid(True, zorder=1)
plt.scatter(cities_df["Lat"], cities_df["Humidity"], marker="H", color = 'purple', zorder=2)
plt.title(f"City Latitude vs Humidity (" + time.strftime("%m/%d/%Y") + ")", fontsize=24)
plt.xlabel("City Latitude", fontsize=18)
plt.ylabel("Humidity (%)", fontsize=18)
plt.savefig("LATvsHUMIDITY.png")
plt.show()

# %%
# Cloudiness (%) vs. Latitude

plt.figure(figsize=(15, 10))
plt.grid(True, zorder=1)
plt.scatter(cities_df["Lat"], cities_df["Cloudiness"], marker="H", color = 'purple', zorder=2)
plt.title(f"City Latitude vs Cloudiness (" + time.strftime("%m/%d/%Y") + ")", fontsize=24)
plt.xlabel("City Latitude", fontsize=18)
plt.ylabel("Cloudiness (%)", fontsize=18)
plt.savefig("LATvsCLOUDINESS.png")
plt.show()

# %%
# Wind Speed (mph) vs. Latitude

plt.figure(figsize=(15, 10))
plt.grid(True, zorder=1)
plt.scatter(cities_df["Lat"], cities_df["Wind Speed"], marker="H", color = 'purple', zorder=2)
plt.title(f"City Latitude vs Wind Speed (" + time.strftime("%m/%d/%Y") + ")", fontsize=24)
plt.xlabel("City Latitude", fontsize=18)
plt.ylabel("Wind Speed (mph)", fontsize=18)
plt.savefig("LATvsWINDSPEED.png")
plt.show()

# %% [markdown]
# ANALYSIS
#
# 1. Humidity and Wind Speed appear to have an inverse relationship. This seems logical when thinking about it, so I found the following article: https://www.brighthub.com/environment/science-environmental/articles/110665.aspx; which states: "The speed of wind is an important factor in the rate of this evaporation because the wind moves humid air away and pulls in drier air, thus increasing the rate of evaporation".
#
# 2. There does not seem to be any correlation between latitude and cloudiness. I expected to find some correlation, as I guessed that the differnt climate zones. Climate zones must not affect the amount of clouds.
#
# 3. Max Temperature is clearly affected by latitude. You can even notice the difference between the Northern and Southern Hemispheres when comparing any latitude value against it's negative value. (For example, -40 latitude has temperatures in the 50s and 70s, whereas 40 latitude has temperatures in the 30s and 50s. I assume this is because of the Earth's tilt and the Southern Hemisphere being closer to the Sun.
